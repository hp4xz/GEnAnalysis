# %%
import ROOT as r
import math
import array
import os
import sys
import matplotlib.pyplot as plt
import numpy as np

#______________Add include directory_______________
current_dir = os.getcwd()
include_dir = os.path.join(current_dir, '../include')
sys.path.insert(0, include_dir)
#__________________________________________________
import ERROR
import CONFIG
import DBPARSE
from ASYMMETRY import *
from UTILITIES import *
from SIMFITS import DistributionFits
from ROOT import gStyle, TChain, TH1F, TCanvas, TLegend


from joblib import Parallel, delayed

# %%
pas="1"
config="3"

# %% [markdown]
# # Cuts

# %%
W2min=CONFIG.Function_JSON("W2min",f"../config/cuts{config}.cfg")
W2max=CONFIG.Function_JSON("W2max",f"../config/cuts{config}.cfg")
dxmin=CONFIG.Function_JSON("dxmin",f"../config/cuts{config}.cfg")
dxmax=CONFIG.Function_JSON("dxmax",f"../config/cuts{config}.cfg")
dymin=CONFIG.Function_JSON("dymin",f"../config/cuts{config}.cfg")
dymax=CONFIG.Function_JSON("dymax",f"../config/cuts{config}.cfg")
dybgmin=CONFIG.Function_JSON("dybgmin",f"../config/cuts{config}.cfg")
dybgmax=CONFIG.Function_JSON("dybgmax",f"../config/cuts{config}.cfg")
coinmin=CONFIG.Function_JSON("coinmin",f"../config/cuts{config}.cfg")
coinmax=CONFIG.Function_JSON("coinmax",f"../config/cuts{config}.cfg")

print(f'W2min: {W2min}')
print(f'W2max: {W2max}')
print(f'dxmin: {dxmin}')
print(f'dxmax: {dxmax}')
print(f'dymin: {dymin}')
print(f'dymax: {dymax}')
print(f'dybgmin: {dybgmin}')
print(f'dybgmax: {dybgmax}')
print(f'Coin Min: {coinmin} Coin Max: {coinmax}')
# Out:
# W2min: 0
# W2max: 1.4947
# dxmin: -0.4
# dxmax: 0.402
# dymin: -0.7895
# dymax: 0.7895
# dybgmin: -1.2
# dybgmax: 1.2
# Coin Min: 82 Coin Max: 106

# %%
cut="w2"
value=[W2min,W2max]

# %%
#w2
cutw2="w2"
valuemaxw2=np.linspace(.2,2.2,175)
valueminw2=np.linspace(0,0,175)

valuew2=np.transpose(np.stack([valueminw2,valuemaxw2],axis=0))

#dy
cutdy="dy"
valuemaxdy=np.linspace(.2,1.5,175)
valuemindy=np.linspace(-.2,-1.5,175)
valuedy=np.transpose(np.stack([valuemindy,valuemaxdy],axis=0))

#dx
cutdx="dx"
valuemaxdx=np.linspace(0.01,1,175)
valuemindx=np.linspace(-.01,-1,175)
valuedx=np.transpose(np.stack([valuemindx,valuemaxdx],axis=0))

# %% [markdown]
# # Calculate Raw Asymmetry, Fit dx and determine fBG, Calc Aphys

# %%
def Function_APHYSSENS(config,cut,value):
    import ROOT as r
    import math
    import array
    import os
    import sys
    import matplotlib.pyplot as plt
    import numpy as np

    #______________Add include directory_______________
    current_dir = os.getcwd()
    include_dir = os.path.join(current_dir, '../include')
    sys.path.insert(0, include_dir)
    #__________________________________________________
    import ERROR
    import CONFIG
    import DBPARSE
    import ASYMMETRY 
    import UTILITIES 
    from SIMFITS import DistributionFits
    from ROOT import gStyle, TChain, TH1F, TCanvas, TLegend


    from joblib import Parallel, delayed
    
    dxmin=CONFIG.Function_JSON("dxmin",f"../config/cuts{config}.cfg")
    dxmax=CONFIG.Function_JSON("dxmax",f"../config/cuts{config}.cfg")
    lower_bound=dxmin
    upper_bound=dxmax
    Raw=ASYMMETRY.Function_ASYMMETRYSENS(config,cut,value)
    print("Raw Asymmetry Calculated")
    
    Fit=ASYMMETRY.Function_FITDXSENS(config,cut,value)
    print("dx Histogram Fit Completed")
    
    data,bg,totalFit,simp,simn=Fit
    bin_centers,bin_contents=bg
    numBG=np.sum(bin_contents[(bin_centers >= lower_bound) & (bin_centers <= upper_bound)])
    bin_centers,bin_contents=data
    numTotal=np.sum(bin_contents[(bin_centers >= lower_bound) & (bin_centers <= upper_bound)])
    fbg=np.round(numBG/numTotal,5)
    
    bin_centers,bin_contents=simn
    Y=np.sum(bin_contents[(bin_centers >= lower_bound) & (bin_centers <= upper_bound)])
    print("Background Fraction Determined")
    
    Phys=ASYMMETRY.Function_APHYS(config,pas,Raw,fbg)
    print("Aphys Calculated")
    
    weighted_A,weighted_A_E,fbg=Phys
    print('Returned: Aphys, Aphys_E, fbg, cut, cutvalue')
    return weighted_A,weighted_A_E,fbg,cut,value,Y

# %%
#Results=Function_APHYSSENS(config,cut,value)

# %% [markdown]
# # GEN2

# %%
config="2"

# %% [markdown]
# # W2

# %%
# %%time
n_jobs = -1  # Use all available CPU cores
Results2w2 = Parallel(n_jobs=n_jobs)(delayed(Function_APHYSSENS)(config,cutw2,val) for (val) in valuew2)
# Out:
# CPU times: user 1.04 s, sys: 802 ms, total: 1.84 s
# Wall time: 25min 52s
# Error in <TList::Clear>: A list is accessing an object (0x867d940) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x867de10) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x867e050) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x86b03f0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x86b0760) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x86b0ad0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x86b0f30) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a02870) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a02c80) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a03070) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a03510) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a04f60) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a05470) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a05ef0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a06120) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a06580) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a06e30) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a072a0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a09040) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a09ef0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a0abe0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a0b320) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a0b7d0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a0bb40) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a10070) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a10800) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a11c20) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a11dc0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a12260) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a13020) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a134c0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a13de0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a14640) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a14cf0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7e71e80) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8408ed0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7e72350) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7e72590) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7ea4930) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7ea4ca0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7ea5010) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7ea5470) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81f65a0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81f69b0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81f6da0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81f7240) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81f8c90) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81f91a0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81f9c20) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81f9e50) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81fa2b0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81fab60) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81fafd0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81fcd70) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81fdc20) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81fe910) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81ff050) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81ff500) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81ff870) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8203da0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8204530) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8205950) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8205af0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8205f90) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8206d50) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x82071f0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8207b10) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8208370) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x788c780) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8208a20) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x84093a0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x84095e0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x843b980) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x843bcf0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x843c060) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x843c4c0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x878dc10) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x878e020) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x878e410) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x878e8b0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8790300) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8790810) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8791290) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x87914c0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8791920) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x87921d0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8792640) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x87943e0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8795290) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8795f80) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x87966c0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8796b70) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8796ee0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x879b410) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x879bba0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x879cfc0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x879d160) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x879d600) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x879e3c0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x879e860) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x879f180) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x879f9e0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x87a0090) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x788cc50) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x788ce90) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x78bf230) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x78bf5a0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x78bf910) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x78bfd70) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7c116c0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7c11ad0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7c11ec0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7c12360) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7c13db0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7c142c0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7c14d40) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7c14f70) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7c153d0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7c15c80) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7c160f0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7c17e90) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7c18d40) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7c19a30) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7c1a170) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7c1a620) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7c1a990) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7c1eec0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7c1f650) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7c20a70) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7c20c10) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7c210b0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7c21e70) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7c22310) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7c22c30) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7c23490) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7c23b40) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x86b4c80) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8700a20) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8700ef0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x86b5150) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8701130) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x86b5390) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x87334d0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8733840) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x86e7730) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8733bb0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x86e7aa0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8734010) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x86e7e10) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a85810) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x86e8270) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a85c20) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a399c0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a86010) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a39dd0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a864b0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a3a1c0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a87f00) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a3a660) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a88410) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a3c0b0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a88e90) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a890c0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a3c5c0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a89520) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a3d040) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a89dd0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a3d270) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a8a240) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8a
already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7de8a00) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8c2d5a0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7c0e0c0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7d54110) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xb877e70) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x85d7790) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7df2c10) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x89b0f40) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xa8fe870) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xaf3eb10) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7de7170) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x94b9f70) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x9ebb5c0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x86a5940) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x81695e0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xa77f720) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x91858f0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8e508d0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xa891380) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xb2d8a40) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8e84090) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xab89cf0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8d3e0b0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x89595b0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xaca5960) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xac03c10) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x80e6680) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xbc527e0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xa0b0050) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x9051d60) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7ce27f0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xb368940) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xb984250) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8e9d4c0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x76d6220) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8ad78f0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xb861e80) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7e21ae0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x92eaf90) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x89b1210) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x85e3260) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x858de90) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xaab6200) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x94ba240) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x74f0cc0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x86a5c10) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x85af820) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xa088320) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xb980b90) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8e12700) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7e14cd0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8038e50) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xbdf39a0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x87ec330) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8d5db40) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xbf991d0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7b30ce0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7ffcbf0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xb76c9e0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7de7440) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xa67e580) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x784a2b0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8951010) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xbc5f030) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8e50ba0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8ecacb0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x40616e0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8aba470) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x9534010) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7ddb080) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x92eb260) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xb62a940) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7e018f0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xac21970) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xb85c9e0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x6f27c80) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xaab64d0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xa0885f0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x85afaf0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x869c290) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xb980e60) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xbd63db0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xa80d8a0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x86b33e0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xb868ec0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7e21db0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xbc5da80) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x92c6f40) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x812c410) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7dc8ae0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x9521a60) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x74f0f90) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xb08c8c0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x77d8a50) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x87897c0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x9155ca0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xb854d40) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8df3ca0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7e14fa0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8039120) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xac66570) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x95342e0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x92f7510) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8e93480) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x81925b0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x87ae310) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xaad1cc0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xbc3e4a0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x6f27f50) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x91559d0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8586640) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8753d60) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xa238040) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8d23850) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7bfadd0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7ddb350) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xb7894e0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xb85ccb0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xbe16a30) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xbbc2490) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x83cea60) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x85ab780) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xa61fde0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xac21c40) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x814ddd0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xbf30a30) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xa80db70) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xbd64080) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x83a1cb0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xa5da530) already deleted (list name = THashList)

# %%
A_result_2=np.empty(0)
E_result_2=np.empty(0)
fbg_result_2=np.empty(0)
cut_result_2=np.empty(0)
w2_2=np.empty(0)
Y_2=np.empty(0)


for i in range(0,len(Results2)):
    A_result_2=np.append(A_result_2,Results2[i][0])
    E_result_2=np.append(E_result_2,Results2[i][1])  
    fbg_result_2=np.append(fbg_result_2,Results2[i][2])
    cut_result_2=np.append(cut_result_2,Results2[i][3])
    w2_2=np.append(w2_2,Results2[i][4][1])
    Y_2=np.append(Y_2,Results2[i][5])

# %%
plt.errorbar(w2_2,A_result_2,E_result_2,fmt='.',ecolor='black',color='red',lw=.8)
#plt.plot(w2_2,Y_2)
#plt.yscale('log')
plt.ylim(0,.5)
plt.title("$A_{phys}$ vs $W^2$ cut GEN"+config)
plt.xlabel("$W^2$ GeV")
plt.ylabel("$A_{phys}$")
# Out:
# Text(0, 0.5, '$A_{phys}$')

# %% [markdown]
# # dY

# %%
# %%time
n_jobs = -1  # Use all available CPU cores
Results2dy = Parallel(n_jobs=n_jobs)(delayed(Function_APHYSSENS)(config,cutdy,val) for (val) in valuedy)
# Out:
# CPU times: user 937 ms, sys: 682 ms, total: 1.62 s
# Wall time: 25min 43s

# %%
A_result_2dy=np.empty(0)
E_result_2dy=np.empty(0)
fbg_result_2dy=np.empty(0)
cut_result_2dy=np.empty(0)
w2_2dy=np.empty(0)
Y_2dy=np.empty(0)


for i in range(0,len(Results4)):
    A_result_2dy=np.append(A_result_2dy,Results2dy[i][0])
    E_result_2dy=np.append(E_result_2dy,Results2dy[i][1])  
    fbg_result_2dy=np.append(fbg_result_2dy,Results2dy[i][2])
    cut_result_2dy=np.append(cut_result_2dy,Results2dy[i][3])
    w2_2dy=np.append(w2_2dy,Results2dy[i][4][1])
    Y_2dy=np.append(Y_2dy,Results2dy[i][5])

# %%
tempor=np.arange(0,len(w2_2dy))
plt.plot(tempor,w2_2dy,'.')

# %%
plt.errorbar(w2_2dy,A_result_2dy,E_result_2dy,fmt='.',ecolor='black',color='red',lw=.8)
plt.title("$A_{phys}$ vs $\Delta Y$ cut GEN"+config)
plt.xlabel("$\Delta Y$ GeV")
plt.ylabel("$A_{phys}$")
# Out:
# Text(0, 0.5, '$A_{phys}$')

# %% [markdown]
# # dx

# %%
# %%time
n_jobs = -1  # Use all available CPU cores
Results2dx = Parallel(n_jobs=n_jobs)(delayed(Function_APHYSSENS)(config,cutdx,val) for (val) in valuedx)
# Out:
# CPU times: user 909 ms, sys: 691 ms, total: 1.6 s
# Wall time: 25min 22s

# %%
A_result_2dx=np.empty(0)
E_result_2dx=np.empty(0)
fbg_result_2dx=np.empty(0)
cut_result_2dx=np.empty(0)
dx_2=np.empty(0)
Y_2dx=np.empty(0)


for i in range(0,len(Results2dx)):
    A_result_2dx=np.append(A_result_2dx,Results2dx[i][0])
    E_result_2dx=np.append(E_result_2dx,Results2dx[i][1])  
    fbg_result_2dx=np.append(fbg_result_2dx,Results2dx[i][2])
    cut_result_2dx=np.append(cut_result_2dx,Results2dx[i][3])
    dx_2=np.append(dx_2,Results2dx[i][4][1])
    Y_2dx=np.append(Y_2dx,Results2dx[i][5])

# %%
plt.errorbar(dx_2,A_result_2dx,E_result_2dx,fmt='.',ecolor='black',color='orange',lw=.7)
plt.title("$A_{phys}$ vs $\Delta X$ cut GEN"+config)
plt.xlabel("$\Delta X$ GeV")
plt.grid()
plt.ylabel("$A_{phys}$")
# Out:
# Text(0, 0.5, '$A_{phys}$')

# %% [markdown]
# # GEN3

# %%
config="3"

# %% [markdown]
# # W2

# %%
# %%time
pas="1"
n_jobs = -1  # Use all available CPU cores
Results3 = Parallel(n_jobs=n_jobs)(delayed(Function_APHYSSENS)(config,cutw2,val) for (val) in valuew2)
# Out:
# CPU times: user 959 ms, sys: 696 ms, total: 1.66 s
# Wall time: 26min 41s

# %%
A_result_3=np.empty(0)
E_result_3=np.empty(0)
fbg_result_3=np.empty(0)
cut_result_3=np.empty(0)
w2_3=np.empty(0)
Y_3=np.empty(0)


for i in range(0,len(Results3)):
    A_result_3=np.append(A_result_3,Results3[i][0])
    E_result_3=np.append(E_result_3,Results3[i][1])  
    fbg_result_3=np.append(fbg_result_3,Results3[i][2])
    cut_result_3=np.append(cut_result_3,Results3[i][3])
    w2_3=np.append(w2_3,Results3[i][4][1])
    Y_3=np.append(Y_3,Results3[i][5])

# %%
plt.plot(w2,Y)

# %%
plt.errorbar(w2,A_result,E_result,fmt='.',ecolor='black',color='orange',lw=.8)
plt.ylim(-.4,0)
plt.title("$A_{phys}$ vs $W^2$ cut GEN"+config)
plt.xlabel("$W^2$ GeV")
plt.ylabel("$A_{phys}$")
# Out:
# Text(0, 0.5, '$A_{phys}$')

# %% [markdown]
# # dy

# %%
# %%time
n_jobs = -1  # Use all available CPU cores
Results3dy = Parallel(n_jobs=n_jobs)(delayed(Function_APHYSSENS)(config,cutdy,val) for (val) in valuedy)
# Out:
# CPU times: user 981 ms, sys: 689 ms, total: 1.67 s
# Wall time: 26min 26s

# %%
A_result_3dy=np.empty(0)
E_result_3dy=np.empty(0)
fbg_result_3dy=np.empty(0)
cut_result_3dy=np.empty(0)
w2_3dy=np.empty(0)
Y_3dy=np.empty(0)


for i in range(0,len(Results3dy)):
    A_result_3dy=np.append(A_result_3dy,Results3dy[i][0])
    E_result_3dy=np.append(E_result_3dy,Results3dy[i][1])  
    fbg_result_3dy=np.append(fbg_result_3dy,Results3dy[i][2])
    cut_result_3dy=np.append(cut_result_3dy,Results3dy[i][3])
    w2_3dy=np.append(w2_3dy,Results3dy[i][4][1])
    Y_3dy=np.append(Y_3dy,Results3dy[i][5])

# %%
plt.errorbar(w2_3dy,A_result_3dy,E_result_3dy,fmt='.',ecolor='black',color='red',lw=.8)
plt.title("$A_{phys}$ vs $\Delta Y$ cut GEN"+config)
plt.xlabel("$\Delta Y$ GeV")
plt.ylabel("$A_{phys}$")
# Out:
# Text(0, 0.5, '$A_{phys}$')

# %%
len(w2_3dy)
# Out:
# 100

# %% [markdown]
# # dx

# %%
# %%time
n_jobs = -1  # Use all available CPU cores
Results3dx = Parallel(n_jobs=n_jobs)(delayed(Function_APHYSSENS)(config,cutdx,val) for (val) in valuedx)
# Out:
# /home/research/.local/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py:700: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# CPU times: user 1.03 s, sys: 878 ms, total: 1.9 s
# Wall time: 26min 5s
# Error in <TList::Clear>: A list is accessing an object (0x888c290) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x75ae050) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x88c2870) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x88c2ab0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x88c2cc0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x88c3030) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x88c33a0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x88c3800) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x75e4630) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x88c3bc0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x75e4870) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8c13630) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x75e4a80) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8c13a20) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x75e4df0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8c14120) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x75e5160) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8c14510) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x75e55c0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8c148d0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x75e5980) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8c14ce0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7934c50) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8c152a0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7935040) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8c156d0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7935740) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8c17fd0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7935b30) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8c183e0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7935ef0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8c187f0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7936300) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8c18c90) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x79368c0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8c1a6e0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7936cf0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8c1abf0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x79395f0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8c1b670) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7939a00) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8c1b8a0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7939e10) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8c1bd00) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x793a2b0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8c1c5b0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x793bd00) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8c1ca20) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x793c210) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8c1e7c0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x793cc90) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8c1f670) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x793cec0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8c20360) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x793d320) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8c20aa0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x793dbd0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8c20f50) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x793e040) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8c212c0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x793fde0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8c21860) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7940c90) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8c21d50) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7941980) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8c26280) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x79420c0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8c26a10) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7942570) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8c27e30) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x79428e0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8c27fd0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7942e80) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8c28470) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7943370) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8c29230) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x79478a0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8c296d0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7948030) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8c10940) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7949450) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8c112b0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x79495f0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7949a90) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x794a850) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x794acf0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7931f60) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x79328d0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7815520) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x784bb00) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x784bd40) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x784bf50) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x784c2c0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x784c630) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x784ca90) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x784ce50) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7b9c990) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7b9cd80) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7b9d480) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7b9d870) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7b9dc30) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7b9e040) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7b9e600) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7b9ea30) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7ba1330) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7ba1740) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7ba1b50) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7ba1ff0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7ba3a40) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7ba3f50) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7ba49d0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7ba4c00) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7ba5060) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7ba5910) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7ba5d80) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7ba7b20) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7ba89d0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7ba96c0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7ba9e00) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7baa2b0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7baa620) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7baabc0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7bab0b0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7baf5e0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7bafd70) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7bb1190) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7bb1330) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7bb17d0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7bb2590) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7bb2a30) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7b99d70) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7b9a6e0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6f72c80) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6fa9260) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6fa94a0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6fa96b0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6fa9a20) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6fa9d90) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6faa1f0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6faa5b0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x72f98a0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x72f9c90) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x72fa390) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x72fa780) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x72fab40) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x72faf50) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x72fb510) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x72fb940) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x72fe240) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x72fe650) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x72fea60) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x72fef00) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7300950) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7300e60) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x73018e0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7301b10) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7301f70) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7302820) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7302c90) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7304a30) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x73058e0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x73065d0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7306d10) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x73071c0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7307530) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7307ad0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7307fc0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x730c4f0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x730cc80) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x730e0a0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x730e240) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x730e6e0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x730f4a0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x730f940) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x72f6bb0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x72f7520) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6ae6660) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6b1cc40) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6b1ce80) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6b1d090) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6b1d400) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6b1d770) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6b1dbd0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6b1df90) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6e6df90) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6e6e380) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6e6ea80) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6e
already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x753a780) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x753ae80) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x753b270) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x753b630) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x753ba40) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x753c000) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x753c430) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x753ed30) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x753f140) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x753f550) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x753f9f0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7541440) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7541950) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x75423d0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7542600) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7542a60) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7543310) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7543780) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7545520) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x75463d0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x75470c0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7547800) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7547cb0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7548020) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x75485c0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7548ab0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x754cfe0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x754d770) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x754eb90) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x754ed30) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x754f1d0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x754ff90) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7550430) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7537770) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x75380e0) already deleted (list name = TList)
# Error in <THashList::Delete>: A list is accessing an object (0xaab52d0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8300260) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8594840) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8e5b320) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8eb9a20) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7a481a0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xa5d7c00) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x6e3fd60) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7ca51d0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8119640) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x71148f0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x800c530) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x96e22b0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7691150) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x74998b0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7539d00) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xaa8ce20) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x97ac2a0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7de4e30) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x75978c0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x935fa70) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x711cdc0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x87a8d20) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x6e83a70) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x81fbf60) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x763d000) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7823680) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x6f21b30) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x74283c0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x788a0b0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7800ef0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7640190) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x96ddef0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x97abfd0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x4512c40) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7d6f9f0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xa3f1600) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x71257c0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x89a35c0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x91a6ae0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7821e00) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x96d6c30) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xa71a740) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7495be0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x758ed50) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xa74de90) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8857040) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7d3e5b0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xaffcaf0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xba20460) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xab0f400) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7670c20) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xb3c93c0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7862c60) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x764fb50) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xb21d0f0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xa90df10) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x947c7d0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x82e3ea0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x72ea030) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x9d0f6b0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xb39df00) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xaa07cd0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x76fa640) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x909fa60) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7862990) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x82fe590) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x9afb890) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xb17d8c0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x75975f0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8a98f40) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x6e837a0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x83bf050) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xb21ce20) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xb86fce0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x6f21860) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xaa07a00) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x9d0f3e0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x96165b0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x9357140) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7b3a6d0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xa26ec90) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xc899260) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xb7fce10) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x82e1680) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8389550) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xc205aa0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xb42a8b0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xca31220) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xaee5920) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xb293d50) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x6f59b40) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7ca9570) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xb17b6e0) already deleted (list name = THashList)

# %%
A_result_3dx=np.empty(0)
E_result_3dx=np.empty(0)
fbg_result_3dx=np.empty(0)
cut_result_3dx=np.empty(0)
dx_3=np.empty(0)
Y_3dx=np.empty(0)


for i in range(0,len(Results3dx)):
    A_result_3dx=np.append(A_result_3dx,Results3dx[i][0])
    E_result_3dx=np.append(E_result_3dx,Results3dx[i][1])  
    fbg_result_3dx=np.append(fbg_result_3dx,Results3dx[i][2])
    cut_result_3dx=np.append(cut_result_3dx,Results3dx[i][3])
    dx_3=np.append(dx_3,Results3dx[i][4][1])
    Y_3dx=np.append(Y_3dx,Results3dx[i][5])

# %%
plt.errorbar(dx_3,A_result_3dx,E_result_3dx,fmt='.',ecolor='black',color='orange',lw=.8)
plt.title("$A_{phys}$ vs $\Delta X$ cut GEN"+config)
plt.xlabel("$\Delta X$ GeV")
plt.ylabel("$A_{phys}$")
plt.ylim(-.5,0)
plt.grid()

# %% [markdown]
# # GEN4

# %% [markdown]
# # W2

# %%
config="4"

# %%
# %%time
pas="1"
n_jobs = -1  # Use all available CPU cores
Results4= Parallel(n_jobs=n_jobs)(delayed(Function_APHYSSENS)(config,cutw2,val) for (val) in valuew2)
# Out:
# CPU times: user 545 ms, sys: 422 ms, total: 967 ms
# Wall time: 8min 45s
# Error in <TList::Clear>: A list is accessing an object (0x6bd9f40) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x73e1680) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x69fa7f0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6bda410) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x73e1b50) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6bda650) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x73e1d90) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6bda860) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x73e1fa0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6bdabd0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x73e2310) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6bdaf40) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x73e2680) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6bf3610) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x73fad50) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6bf39d0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x73fb110) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6bf4350) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x73fb9c0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6bf4740) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x73fbdb0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6f50310) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7759960) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6f50700) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7759d50) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6f50ac0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x775a110) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6f50ed0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x775a520) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x69facc0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6f51490) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x775aae0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6f518c0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x775af10) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x69faf00) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6f541c0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x
already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x9002d50) already deleted (list name = THashList)

# %%
A_result_4=np.empty(0)
E_result_4=np.empty(0)
fbg_result_4=np.empty(0)
cut_result_4=np.empty(0)
w2_4=np.empty(0)
Y_4=np.empty(0)


for i in range(0,len(Results4)):
    A_result_4=np.append(A_result_4,Results4[i][0])
    E_result_4=np.append(E_result_4,Results4[i][1])  
    fbg_result_4=np.append(fbg_result_4,Results4[i][2])
    cut_result_4=np.append(cut_result_4,Results4[i][3])
    w2_4=np.append(w2_4,Results4[i][4][1])
    Y_4=np.append(Y_4,Results4[i][5])

# %%
plt.errorbar(w2_4,A_result_4,E_result_4,fmt='.',ecolor='black',color='red',lw=.8)
plt.title("$A_{phys}$ vs $W^2$ cut GEN"+config)
plt.xlabel("$W^2$ GeV")
plt.ylabel("$A_{phys}$")
# Out:
# Text(0, 0.5, '$A_{phys}$')

# %% [markdown]
# # dy

# %%
# %%time
n_jobs = -1  # Use all available CPU cores
Results4dy = Parallel(n_jobs=n_jobs)(delayed(Function_APHYSSENS)(config,cutdy,val) for (val) in valuedy)
# Out:
# CPU times: user 514 ms, sys: 246 ms, total: 760 ms
# Wall time: 8min 53s

# %%
A_result_4dy=np.empty(0)
E_result_4dy=np.empty(0)
fbg_result_4dy=np.empty(0)
cut_result_4dy=np.empty(0)
w2_4dy=np.empty(0)
Y_4dy=np.empty(0)


for i in range(0,len(Results4dy)):
    A_result_4dy=np.append(A_result_4dy,Results4dy[i][0])
    E_result_4dy=np.append(E_result_4dy,Results4dy[i][1])  
    fbg_result_4dy=np.append(fbg_result_4dy,Results4dy[i][2])
    cut_result_4dy=np.append(cut_result_4dy,Results4dy[i][3])
    w2_4dy=np.append(w2_4dy,Results4dy[i][4][1])
    Y_4dy=np.append(Y_4dy,Results4dy[i][5])

# %%
plt.errorbar(w2_4dy,A_result_4dy,E_result_4dy,fmt='.',ecolor='black',color='red',lw=.8)
plt.title("$A_{phys}$ vs $\Delta Y$ cut GEN"+config)
plt.xlabel("$\Delta Y$ GeV")
plt.ylabel("$A_{phys}$")
# Out:
# Text(0, 0.5, '$A_{phys}$')

# %% [markdown]
# # dx

# %%
# %%time
n_jobs = -1  # Use all available CPU cores
Results4dx = Parallel(n_jobs=n_jobs)(delayed(Function_APHYSSENS)(config,cutdx,val) for (val) in valuedx)
# Out:
# /home/research/.local/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py:700: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# CPU times: user 576 ms, sys: 539 ms, total: 1.12 s
# Wall time: 8min 46s
# Error in <TList::Clear>: A list is accessing an object (0x7e37d90) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7e38260) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7e384a0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7e386b0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7e38a20) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7e38d90) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7e51460) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7e51820) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7e520d0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7e524c0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81af300) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81af6f0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81afab0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81afec0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81b0480) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81b08b0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81b31b0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81b35c0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81b39d0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81b3e70) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81b58c0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81b5dd0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81b6850) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81b6a80) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81b6ee0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81b7790) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81b7c00) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81b99a0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81ba850) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81bb540) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81bbc80) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81bc130) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81bc4a0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81bca40) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81bcf30) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81c1460) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81c1bf0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81c3010) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81c31b0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81c3650) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81c4410) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81c48b0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7e32430) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7e32da0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7808c10) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x78090e0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7809320) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7809530) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x78098a0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7809c10) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x78222e0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x78226a0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7822f50) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7823340) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7b80970) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7b80d60) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7b81120) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7b81530) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7b81af0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7b81f20) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7b84820) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7b84c30) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7b85040) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7b854e0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7b86f30) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7b87440) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7b87ec0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7b880f0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7b88550) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7b88e00) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7b89270) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7b8b010) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7b8bec0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7b8cbb0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7b8d2f0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7b8d7a0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7b8db10) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7b8e0b0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7b8e5a0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7b92ad0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7b93260) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7b94680) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7b94820) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7b94cc0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7b95a80) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7b95f20) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x78032b0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7803c20) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7a4b750) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7a4bc20) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7a4be60) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7a4c070) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7a4c3e0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7a4c750) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7a64e20) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7a651e0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7a65a90) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7a65e80) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7dc2ce0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7dc30d0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7dc3490) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7dc38a0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7dc3e60) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7dc4290) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7dc6b90) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7dc6fa0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7dc73b0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7dc7850) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7dc92a0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7dc97b0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7dca230) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7dca460) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7dca8c0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7
) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x85455f0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8545a60) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8547800) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x85486b0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x85493a0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8549ae0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8549f90) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x854a300) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x854a8a0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x854ad90) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x854f2c0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x854fa50) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8550e70) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8551010) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x85514b0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8552270) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x8552710) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81c0410) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x81c0d80) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7881910) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7881de0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7882020) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7882230) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x78825a0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7882910) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x789afe0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x789b3a0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x789bd20) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x789c110) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7bf88f0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7bf8ce0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7bf90a0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7bf94b0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7bf9a70) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7bf9ea0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7bfc7a0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7bfcbb0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7bfcfc0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7bfd460) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7bfeeb0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x7bff3c0) already deleted (list name = TList)
# ...
# Error in <THashList::Delete>: A list is accessing an object (0xa015410) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7dc1a30) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x723ff80) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x87cfb70) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7344050) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x9086920) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x78d9830) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x799d1a0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8b07da0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8af37a0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x877e610) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8ae7590) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xa7f12e0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x86067b0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x94c28a0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x91d50e0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8bd0180) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x73e7050) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7c05f50) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8207c70) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x76e2ae0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x9083460) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x76d12b0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x6bae370) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x9587190) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x6d45f30) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8008b50) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xa6c0dc0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x847a680) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x9a03f00) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x94c25d0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x6446c00) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x819f1d0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x727f800) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7ab63c0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x9245900) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x9c26ea0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x9043800) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7421510) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x75f4b80) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8a8ac40) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x81656b0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xa7e0c40) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7d79900) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xa3553f0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x9a5f220) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x95256a0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xa907bd0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x819ef00) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x82a1a80) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7aa80a0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7621520) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x9c26bd0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8e59f80) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7b4b280) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x6efd940) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x75c5ab0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x76816c0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xa7e0970) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7d79630) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xa2a1690) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x9a96320) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x95253d0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x89925e0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7b55300) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7b9d9b0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8fa1d80) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x761f520) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7a41640) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7223450) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x76b5bd0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8ddd120) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x75f37f0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8f689b0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x95d86b0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x898b570) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8a380f0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x82585c0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7fc9460) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x91cb2f0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7b55030) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7dbd270) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x73e59a0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x9245630) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7a41370) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x78ec790) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x78f96a0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x89f5710) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x75f48b0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x92e3010) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8a37e20) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x898b2a0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x95da6e0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x9d690b0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8092d80) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xa907900) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7fe9a50) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x80f39b0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x76efeb0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8410100) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x852e330) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7c06150) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x79adf80) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x6efc470) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7626990) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8b5ae50) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x79b7450) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8774c90) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x786fa90) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x78f19e0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x9311200) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7929b20) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x87749c0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x76efbe0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x79d4010) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7d98ae0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x80f36e0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x852e060) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8a00840) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x76b5900) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x6efc1a0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7223180) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x786f7c0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x9b19010) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x76266c0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x78f1710) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x9310f30) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x81b4520) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7d73320) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x82999d0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x87b4900) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x9820dd0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7cd75b0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8b4c420) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7d93b80) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xb504950) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x989c2e0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x68e5ca0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8604350) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7444790) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0xa367010) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x86df550) already deleted (list name = THashList)

# %%
A_result_4dx=np.empty(0)
E_result_4dx=np.empty(0)
fbg_result_4dx=np.empty(0)
cut_result_4dx=np.empty(0)
dx_4=np.empty(0)
Y_4dx=np.empty(0)


for i in range(0,len(Results4dx)):
    A_result_4dx=np.append(A_result_4dx,Results4dx[i][0])
    E_result_4dx=np.append(E_result_4dx,Results4dx[i][1])  
    fbg_result_4dx=np.append(fbg_result_4dx,Results4dx[i][2])
    cut_result_4dx=np.append(cut_result_4dx,Results4dx[i][3])
    dx_4=np.append(dx_4,Results4dx[i][4][1])
    Y_4dx=np.append(Y_4dx,Results4dx[i][5])

# %%
plt.errorbar(dx_4,A_result_4dx,E_result_4dx,fmt='.',ecolor='black',color='orange',lw=.8)
plt.title("$A_{phys}$ vs $\Delta X$ cut GEN"+config)
plt.xlabel("$\Delta X$ GeV")
plt.ylabel("$A_{phys}$")
plt.ylim(-.5,.5)
plt.grid()
