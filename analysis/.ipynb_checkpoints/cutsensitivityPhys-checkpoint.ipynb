# %%
import ROOT as r
import math
import array
import os
import sys
import matplotlib.pyplot as plt
import numpy as np

#______________Add include directory_______________
current_dir = os.getcwd()
include_dir = os.path.join(current_dir, '../include')
sys.path.insert(0, include_dir)
#__________________________________________________
import ERROR
import CONFIG
import DBPARSE
from ASYMMETRY import *
from UTILITIES import *
from SIMFITS import DistributionFits
from ROOT import gStyle, TChain, TH1F, TCanvas, TLegend


from joblib import Parallel, delayed
# Out:
# Welcome to JupyROOT 6.26/06

# %%
pas="1"
config="3"

# %% [markdown]
# # Cuts

# %%
W2min=CONFIG.Function_JSON("W2min",f"../config/cuts{config}.cfg")
W2max=CONFIG.Function_JSON("W2max",f"../config/cuts{config}.cfg")
dxmin=CONFIG.Function_JSON("dxmin",f"../config/cuts{config}.cfg")
dxmax=CONFIG.Function_JSON("dxmax",f"../config/cuts{config}.cfg")
dymin=CONFIG.Function_JSON("dymin",f"../config/cuts{config}.cfg")
dymax=CONFIG.Function_JSON("dymax",f"../config/cuts{config}.cfg")
dybgmin=CONFIG.Function_JSON("dybgmin",f"../config/cuts{config}.cfg")
dybgmax=CONFIG.Function_JSON("dybgmax",f"../config/cuts{config}.cfg")
coinmin=CONFIG.Function_JSON("coinmin",f"../config/cuts{config}.cfg")
coinmax=CONFIG.Function_JSON("coinmax",f"../config/cuts{config}.cfg")

print(f'W2min: {W2min}')
print(f'W2max: {W2max}')
print(f'dxmin: {dxmin}')
print(f'dxmax: {dxmax}')
print(f'dymin: {dymin}')
print(f'dymax: {dymax}')
print(f'dybgmin: {dybgmin}')
print(f'dybgmax: {dybgmax}')
print(f'Coin Min: {coinmin} Coin Max: {coinmax}')
# Out:
# W2min: 0
# W2max: 1.4947
# dxmin: -0.4
# dxmax: 0.402
# dymin: -0.7895
# dymax: 0.7895
# dybgmin: -1.2
# dybgmax: 1.2
# Coin Min: 82 Coin Max: 106

# %%
cut="w2"
value=[W2min,W2max]

# %% [markdown]
# # Calculate Asymmetry

# %%
# %%time
Raw=Function_ASYMMETRYSENS(config,cut,value[0])

runs,A,AE,Y,he3Pol,beamPol,cut,cutVal=Raw
# Out:
# Config: 3
# CPU times: user 28.2 s, sys: 1.15 s, total: 29.3 s
# Wall time: 29.3 s
# Error in <THashList::Delete>: A list is accessing an object (0xb567e10) already deleted (list name = THashList)

# %%
cutVal
# Out:
# array([0. , 0.2])

# %%
#w2
valuemax=np.linspace(.2,2,80)
valuemin=np.linspace(0,0,80)

# %%
value=np.transpose(np.stack([valuemin,valuemax],axis=0))

# %%
# %%time
n_jobs = -1  # Use all available CPU cores
Asym_results = Parallel(n_jobs=n_jobs)(delayed(Function_ASYMMETRYSENS)(config,cut,val) for (val) in value)
# Out:
# CPU times: user 330 ms, sys: 265 ms, total: 595 ms
# Wall time: 6min 28s
# Error in <TList::Clear>: A list is accessing an object (0x6731340) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6aa2950) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6ad8e60) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6767850) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6ad90a0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6767a90) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6767ca0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6ad92b0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6768010) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6ad9620) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6768380) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6ad9990) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6ad9df0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x67687e0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6ada1b0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6768ba0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6e021d0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6a90e20) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6e025c0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6a91210) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6e02cc0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6a91910) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6a91d00) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6e030b0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6a920c0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6e03470) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6e03880) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6a924d0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6a92a90) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6e03e40) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6a92ec0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x
) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x74b6610) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x742ce80) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7e19c20) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x6a907a0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x80de310) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x6fb9fa0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7de2600) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x6e01b50) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x78bc760) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8380f90) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7612350) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7e87860) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x785cbd0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7568f10) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7a34a80) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7be5570) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x75c0b40) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x75373b0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8085ab0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x6b9acd0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x822d320) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x6f0c0a0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7f16c30) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7226d50) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x84c6600) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7a16c90) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7eb8770) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7f988a0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x765bf80) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8ed0c10) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7b46490) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7015990) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7f2e940) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x6ce4330) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x763ee80) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8034e30) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x82d35a0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7890440) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7fffa20) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7a3f210) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8374210) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7ac5500) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x76b8a00) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7f377a0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x760dc10) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x833adf0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x78d9d50) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x730c1f0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x6a5d300) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7ead490) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7e3a030) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7de6440) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x6fc5960) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x832fab0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7d9b5f0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7205b00) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x851dba0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8385000) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8376810) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7f36bb0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x833f0d0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x83f2be0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7417960) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x6dc66e0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x749de50) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x74623a0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x748f870) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x82a33e0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7ef4ce0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7fdcb70) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7dcef40) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x6f692d0) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x7af9740) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x8d1c900) already deleted (list name = THashList)

# %%
Asym_array=np.transpose(Asym_results)
# Out:
# /home/research/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:43: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   result = getattr(asarray(obj), method)(*args, **kwds)

# %%
runs,A,AE,Y,he3Pol,beamPol,cut,cutVal=Asym_array

# %% [markdown]
# # rawA

# %%
nP=np.empty(0)
nM=np.empty(0)
for i in range(0,len(Y)):
    P=0
    M=0
    for j in range(0,len(Y[i])):
        P+=(A[i][j]*Y[i][j]+Y[i][j])/2
        M+=-(A[i][j]*Y[i][j]-Y[i][j])/2
    nP=np.append(nP,P)
    nM=np.append(nM,M)

error=np.empty(0)
for i in range(0,len(Y)):
    e=2*np.sqrt(nP[i]*nM[i])/((nP[i]+nM[i])**(3/2))
    error=np.append(error,e)

weightedA=np.empty(0)

for i in range(0,len(A)):
    num=0
    den=0
    numE=0
    denE=0
    for j in range(0,len(A[i])):
        num+=A[i][j]*Y[i][j]
        den+=Y[i][j]
        

    weightedA=np.append(weightedA,num/den)

# %%
cutValue=np.empty(0)
for i in range(0,len(cutVal)):
    cutValue=np.append(cutValue,cutVal[i][1])

# %%
cut[0]
# Out:
# 'w2'

# %%
plt.errorbar(cutValue,weightedA,error,fmt='.',ecolor='black',color='red',lw=.8)
plt.ylim(-.06,.06)
plt.ylabel("$A_{Raw}$")
plt.title(f"Raw Asymmetry vs $W^2$ Cut GEN{config}")
plt.xlabel("$W^2$ Cut (GeV)")
plt.grid()
plt.savefig(f"../plots/CUTSENSITIVITY/GEN{config}/{cut[0]}.png")

# %% [markdown]
# # Bring In Corrections

# %%
facc=np.sum(np.load(f'CorrectionArrays/Pass{pas}/facc{config}.npy'))
Efacc=.05*facc
Aacc=np.sum(np.load(f'CorrectionArrays/Pass{pas}/Aacc{config}.npy'))
Eacc=.05*Aacc

fproton=np.sum(np.load(f'CorrectionArrays/Pass{pas}/fproton{config}.npy'))
Efproton=.005*fproton
Aproton=np.sum(np.load(f'CorrectionArrays/Pass{pas}/Aproton{config}.npy'))
Eproton=.005*Aproton

fpion=0
Efpion=.005*fpion
Apion=0
Epion=.005*Apion

fFSI=0
EfFSI=.005*fFSI
AFSI=0
EFSI=.005*AFSI

fnitro=.05
Efnitro=.005*fnitro

Pneutron=.85
Eneutron=.005*Pneutron

fbg=np.sum(np.load(f'CorrectionArrays/Pass{pas}/fbg{config}.npy'))-fpion-facc-fFSI-fnitro
Efbg=0.05*fbg
Abg=np.sum(np.load(f'CorrectionArrays/Pass{pas}/Abg{config}.npy'))
Ebg=np.sum(np.load(f'CorrectionArrays/Pass{pas}/AbgE{config}.npy'))

#----------------------------------------------------------
farray=[facc,fproton,fbg,fpion,fFSI]
Efarray1=[Efacc,Efproton,Efbg,Efpion,EfFSI]
Efarray2=[Efacc,Efproton,Efbg,Efpion,EfFSI,Efnitro]

Aarray=[Aacc,Aproton,Abg,Apion,AFSI]
AEarray=[Eacc,Eproton,Ebg,Epion,EFSI]

fAE=ERROR.Function_f_A_ERROR(farray,Efarray1,Aarray,AEarray)
fE=ERROR.Function_f_ERROR(Efarray2)
#----------------------------------------------------------
fA= facc*Aacc + fproton*Aproton + fbg*Abg + fpion*Apion + fFSI*AFSI

f=facc + fproton + fbg + fpion + fFSI 
print(f'Accidentals f:{facc} A:{np.round(Aacc,3)} f*A:{np.round(facc*Aacc,5)}')
print(f'Proton----- f:{fproton} A:{np.round(Aproton,6)} f*A:{np.round(fproton*Aproton,8)}')
print(f'Background- f:{fbg} A:{np.round(Abg,3)} f*A:{np.round(fbg*Abg,5)}')
print(f'Pion------- f:{fpion} A:{np.round(Apion,3)} f*A:{np.round(fpion*Apion,5)}')
print(f'FSI-------- f:{fFSI} A:{np.round(AFSI,3)} f*A:{np.round(fFSI*AFSI,5)}')
print(f'Nitrogen--- f:{fnitro}')
print(f'Sum of all Correction fractions times Asymmetry: {np.round(fA,5)}')
# Out:
# Accidentals f:0.103 A:-0.01 f*A:-0.001
# Proton----- f:0.027 A:1.9e-05 f*A:5.2e-07
# Background- f:0.47300000000000003 A:0.004 f*A:0.00169
# Pion------- f:0 A:0 f*A:0
# FSI-------- f:0 A:0 f*A:0
# Nitrogen--- f:0.05
# Sum of all Correction fractions times Asymmetry: 0.00069

# %% [markdown]
# # Calculate $A_{\text{Phys}}$

# %%
newA=np.array(A)
newYield=np.array(Y)

weightedSum=0
sumWeights=0


polsum=np.empty(0)

precorrection=0
precorrectionW=0
for i in range(0,len(newA)):
    
    PbE=.03*beamPol[i]/100
    PtE=.03*he3Pol[i]/100
    precorrection+=newA[i]*newYield[i]
    precorrectionW+=newYield[i]
    calculate=ERROR.Function_WEIGHTEDAVERAGEAPHYS(newA[i],fA,f,fnitro,beamPol[i]/100,Pneutron,he3Pol[i]/100,AE[i],fAE,fE,Efnitro,PbE,Eneutron,PtE)
    w=calculate[0]
    w_sig= calculate[1] 
    weightedSum+=(w/(w_sig**2))
    sumWeights+=1/(w_sig**2)
    


    
weighted_A=weightedSum/sumWeights
weighted_A_E=math.sqrt(1/sumWeights)

# %%
print(f'A_phys= {np.round(weighted_A,5)} +/- {np.round(weighted_A_E,5)}')

plt.figure(figsize=(11,4))
plt.title("$A_{Phys}$ By Run Number")
plt.xlabel("Run Number")
plt.ylabel("$A_{Phys}$")
plt.errorbar(runs,A,yerr=AE,fmt='.',ecolor='black',color='red',lw=.8)
# Out:
# A_phys= -0.29361 +/- 0.04284
# <ErrorbarContainer object of 3 artists>
