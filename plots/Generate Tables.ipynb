# %%
import pandas as pd
import sys
import os
import matplotlib.pyplot as plt
import numpy as np
#______________Add include directory_______________
current_dir = os.getcwd()
include_dir = os.path.join(current_dir, '../include')
sys.path.insert(0, include_dir)
#__________________________________________________
import CONFIG

# %% [markdown]
# # Quasi Elastic Cuts

# %%
pas="1"

# %%
config="2"
W2min=CONFIG.Function_JSON("W2min",f"../config/cuts{config}.cfg")
W2max=CONFIG.Function_JSON("W2max",f"../config/cuts{config}.cfg")
dxmin=CONFIG.Function_JSON("dxmin",f"../config/cuts{config}.cfg")
dxmax=CONFIG.Function_JSON("dxmax",f"../config/cuts{config}.cfg")
dymin=CONFIG.Function_JSON("dymin",f"../config/cuts{config}.cfg")
dymax=CONFIG.Function_JSON("dymax",f"../config/cuts{config}.cfg")
dybgmin=CONFIG.Function_JSON("dybgmin",f"../config/cuts{config}.cfg")
dybgmax=CONFIG.Function_JSON("dybgmax",f"../config/cuts{config}.cfg")
coinmin=CONFIG.Function_JSON("coinmin",f"../config/cuts{config}.cfg")
coinmax=CONFIG.Function_JSON("coinmax",f"../config/cuts{config}.cfg")
data = {
    "Cut": ["$W^2$ (GeV$^2$)", "$\Delta X$ (m)", "$\Delta Y$ (m)", "$\Delta Y bg$ (m)", "Coincidence (ns)"],
    "Min": [W2min, dxmin, dymin, dybgmin, coinmin],
    "Max": [W2max, dxmax, dymax, dybgmax, coinmax]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Plot the DataFrame using matplotlib
fig, ax = plt.subplots(figsize=(8, 4),dpi=200)  # set size frame
ax.axis('tight')
ax.axis('off')

# Create the table
table = ax.table(cellText=df.values, colLabels=df.columns, cellLoc='center', loc='center')

# Add the additional row above the table
ncols = len(df.columns)
ax.text(0.5, .85, 'GEN2', horizontalalignment='center', verticalalignment='center', transform=ax.transAxes, fontsize=12, fontweight='bold')

# Adjust the table position to fit the additional row
table.scale(1.2, 1.2)
table.auto_set_font_size(False)
table.set_fontsize(12)
plt.subplots_adjust(top=0.8)
for (i, j), cell in table.get_celld().items():
    if i == 0:
        cell.set_text_props(fontsize=12, weight='bold')
    if j == 0 and i > 0:
        cell.set_text_props(fontsize=14)

# Adjust column widths and cell padding
table.auto_set_column_width([0, 1, 2])
for (i, j), cell in table.get_celld().items():
    cell.set_edgecolor('black')
    cell.set_linewidth(1.5)
    cell.set_height(0.1)
    cell.set_text_props(ha='center', va='center')
plt.savefig(f"tables/cutsGEN{config}")

# %%
config="3"

W2min=CONFIG.Function_JSON("W2min",f"../config/cuts{config}.cfg")
W2max=CONFIG.Function_JSON("W2max",f"../config/cuts{config}.cfg")
dxmin=CONFIG.Function_JSON("dxmin",f"../config/cuts{config}.cfg")
dxmax=CONFIG.Function_JSON("dxmax",f"../config/cuts{config}.cfg")
dymin=CONFIG.Function_JSON("dymin",f"../config/cuts{config}.cfg")
dymax=CONFIG.Function_JSON("dymax",f"../config/cuts{config}.cfg")
dybgmin=CONFIG.Function_JSON("dybgmin",f"../config/cuts{config}.cfg")
dybgmax=CONFIG.Function_JSON("dybgmax",f"../config/cuts{config}.cfg")
coinmin=CONFIG.Function_JSON("coinmin",f"../config/cuts{config}.cfg")
coinmax=CONFIG.Function_JSON("coinmax",f"../config/cuts{config}.cfg")
data = {
    "Cut": ["$W^2$ (GeV$^2$)", "$\Delta X$ (m)", "$\Delta Y$ (m)", "$\Delta Y bg$ (m)", "Coincidence (ns)"],
    "Min": [W2min, dxmin, dymin, dybgmin, coinmin],
    "Max": [W2max, dxmax, dymax, dybgmax, coinmax]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Plot the DataFrame using matplotlib
fig, ax = plt.subplots(figsize=(8, 4))  # set size frame
ax.axis('tight')
ax.axis('off')

# Create the table
table = ax.table(cellText=df.values, colLabels=df.columns, cellLoc='center', loc='center')

# Add the additional row above the table
ncols = len(df.columns)
ax.text(0.5, .85, 'GEN3', horizontalalignment='center', verticalalignment='center', transform=ax.transAxes, fontsize=12, fontweight='bold')

# Adjust the table position to fit the additional row
table.scale(1.2, 1.2)
table.auto_set_font_size(False)
table.set_fontsize(12)
plt.subplots_adjust(top=0.8)
for (i, j), cell in table.get_celld().items():
    if i == 0:
        cell.set_text_props(fontsize=12, weight='bold')
    if j == 0 and i > 0:
        cell.set_text_props(fontsize=14)

# Adjust column widths and cell padding
table.auto_set_column_width([0, 1, 2])
for (i, j), cell in table.get_celld().items():
    cell.set_edgecolor('black')
    cell.set_linewidth(1.5)
    cell.set_height(0.1)
    cell.set_text_props(ha='center', va='center')
plt.savefig(f"tables/cutsGEN{config}")

# %%
config="4"
W2min=CONFIG.Function_JSON("W2min",f"../config/cuts{config}.cfg")
W2max=CONFIG.Function_JSON("W2max",f"../config/cuts{config}.cfg")
dxmin=CONFIG.Function_JSON("dxmin",f"../config/cuts{config}.cfg")
dxmax=CONFIG.Function_JSON("dxmax",f"../config/cuts{config}.cfg")
dymin=CONFIG.Function_JSON("dymin",f"../config/cuts{config}.cfg")
dymax=CONFIG.Function_JSON("dymax",f"../config/cuts{config}.cfg")
dybgmin=CONFIG.Function_JSON("dybgmin",f"../config/cuts{config}.cfg")
dybgmax=CONFIG.Function_JSON("dybgmax",f"../config/cuts{config}.cfg")
coinmin=CONFIG.Function_JSON("coinmin",f"../config/cuts{config}.cfg")
coinmax=CONFIG.Function_JSON("coinmax",f"../config/cuts{config}.cfg")
data = {
    "Cut": ["$W^2$ (GeV$^2$)", "$\Delta X$ (m)", "$\Delta Y$ (m)", "$\Delta Y bg$ (m)", "Coincidence (ns)"],
    "Min": [W2min, dxmin, dymin, dybgmin, coinmin],
    "Max": [W2max, dxmax, dymax, dybgmax, coinmax]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Plot the DataFrame using matplotlib
fig, ax = plt.subplots(figsize=(8, 4))  # set size frame
ax.axis('tight')
ax.axis('off')

# Create the table
table = ax.table(cellText=df.values, colLabels=df.columns, cellLoc='center', loc='center')

# Add the additional row above the table
ncols = len(df.columns)
ax.text(0.5, .85, 'GEN4', horizontalalignment='center', verticalalignment='center', transform=ax.transAxes, fontsize=12, fontweight='bold')

# Adjust the table position to fit the additional row
table.scale(1.2, 1.2)
table.auto_set_font_size(False)
table.set_fontsize(12)
plt.subplots_adjust(top=0.8)
for (i, j), cell in table.get_celld().items():
    if i == 0:
        cell.set_text_props(fontsize=12, weight='bold')
    if j == 0 and i > 0:
        cell.set_text_props(fontsize=14)

# Adjust column widths and cell padding
table.auto_set_column_width([0, 1, 2])
for (i, j), cell in table.get_celld().items():
    cell.set_edgecolor('black')
    cell.set_linewidth(1.5)
    cell.set_height(0.1)
    cell.set_text_props(ha='center', va='center')
plt.savefig(f"tables/cutsGEN{config}")

# %% [markdown]
# # Corrections

# %%
config="2"
facc=np.sum(np.load(f'../analysis/CorrectionArrays/Pass{pas}/facc{config}.npy'))
Efacc=np.sum(np.load(f'../analysis/CorrectionArrays/Pass{pas}/faccE{config}.npy'))
Aacc=np.sum(np.load(f'../analysis/CorrectionArrays/Pass{pas}/Aacc{config}.npy'))
Eacc=np.sum(np.load(f'../analysis/CorrectionArrays/Pass{pas}/AaccE{config}.npy'))

fproton=np.sum(np.load(f'../analysis/CorrectionArrays/Pass{pas}/fproton{config}.npy'))
Efproton=np.sum(np.load(f'../analysis/CorrectionArrays/Pass{pas}/fprotonE{config}.npy'))
Aproton=np.sum(np.load(f'../analysis/CorrectionArrays/Pass{pas}/Aproton{config}.npy'))
Eproton=.005*Aproton

fpion=0
Efpion=.005*fpion
Apion=0
Epion=.005*Apion

fFSI=0
EfFSI=.005*fFSI
AFSI=0
EFSI=.005*AFSI

fnitro=.0157
Efnitro=.005*fnitro

Pneutron=.85
Eneutron=.005*Pneutron

fbg=np.sum(np.load(f'../analysis/CorrectionArrays/Pass{pas}/fbg{config}.npy'))-fpion-facc-fFSI-fnitro
Efbg=np.sum(np.load(f'../analysis/CorrectionArrays/Pass{pas}/fbg{config}.npy'))
Abg=np.sum(np.load(f'../analysis/CorrectionArrays/Pass{pas}/Abg{config}.npy'))
Ebg=np.sum(np.load(f'../analysis/CorrectionArrays/Pass{pas}/AbgE{config}.npy'))

data = {
    "Variable": [
        r"$\mathbf{f_{acc}}$", r"$\mathbf{A_{acc}}$", r"$\mathbf{f_{proton}}$", r"$\mathbf{A_{proton}}$",
        r"$\mathbf{f_{pion}}$", r"$\mathbf{A_{pion}}$", r"$\mathbf{f_{FSI}}$", r"$\mathbf{A_{FSI}}$",
        r"$\mathbf{f_{nitro}}$", r"$\mathbf{P_{neutron}}$", r"$\mathbf{f_{bg}}$", r"$\mathbf{A_{bg}}$"
    ],
    "Value": [
        round(facc, 5), round(Aacc, 5), round(fproton, 5), round(Aproton, 5),
        round(fpion, 5), round(Apion, 5), round(fFSI, 5), round(AFSI, 5),
        round(fnitro, 5), round(Pneutron, 5), round(fbg, 5), round(Abg, 5)
    ],
    r"$\mathbf{\sigma}$": [
        round(Efacc, 5), round(Eacc, 5), round(Efproton, 5), round(Eproton, 5),
        round(Efpion, 5), round(Epion, 5), round(EfFSI, 5), round(EFSI, 5),
        round(Efnitro, 5), round(Eneutron, 5), round(Efbg, 5), round(Ebg, 5)
    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Plot the DataFrame using matplotlib
fig, ax = plt.subplots(figsize=(12, 6))  # set size frame
ax.axis('tight')
ax.axis('off')

# Create the table and adjust the font size
table = ax.table(cellText=df.values, colLabels=[r"$\mathbf{Variable}$", r"$\mathbf{Value}$", r"$\mathbf{\sigma}$"], cellLoc='center', loc='center')
table.auto_set_font_size(False)
table.set_fontsize(12)

# Set a larger font size for the variable column and bold headers
for (i, j), cell in table.get_celld().items():
    if i == 0:
        cell.set_text_props(fontsize=12, weight='bold')
    if j == 0 and i > 0:
        cell.set_text_props(fontsize=14, weight='bold')

# Adjust column widths and cell padding
table.auto_set_column_width([0, 1, 2])
for (i, j), cell in table.get_celld().items():
    cell.set_edgecolor('black')
    cell.set_linewidth(1.5)
    cell.set_height(0.1)
    cell.set_text_props(ha='center', va='center')

# %%
pas="1"

#______________________________________GEN2___________________________________________________
config="2"
facc_GEn2 = np.sum(np.load(f'../analysis/CorrectionArrays/Pass{pas}/facc{config}.npy'))
Efacc_GEn2 = np.sum(np.load(f'../analysis/CorrectionArrays/Pass{pas}/faccE{config}.npy'))
Aacc_GEn2 = np.sum(np.load(f'../analysis/CorrectionArrays/Pass{pas}/Aacc{config}.npy'))
Eacc_GEn2 = np.sum(np.load(f'../analysis/CorrectionArrays/Pass{pas}/AaccE{config}.npy'))

fproton_GEn2 = np.sum(np.load(f'../analysis/CorrectionArrays/Pass{pas}/fproton{config}.npy'))
Efproton_GEn2 = np.sum(np.load(f'../analysis/CorrectionArrays/Pass{pas}/fprotonE{config}.npy'))
Aproton_GEn2 = np.sum(np.load(f'../analysis/CorrectionArrays/Pass{pas}/Aproton{config}.npy'))
Eproton_GEn2 = .005 * Aproton_GEn2

fpion_GEn2 = 0
Efpion_GEn2 = .005 * fpion_GEn2
Apion_GEn2 = 0
Epion_GEn2 = .005 * Apion_GEn2

fFSI_GEn2 = 0
EfFSI_GEn2 = .005 * fFSI_GEn2
AFSI_GEn2 = 0
EFSI_GEn2 = .005 * AFSI_GEn2

fnitro_GEn2 = .0157
Efnitro_GEn2 = .005 * fnitro_GEn2

Pneutron_GEn2 = .95
Eneutron_GEn2 = .005 * Pneutron_GEn2

fbg_GEn2 = np.sum(np.load(f'../analysis/CorrectionArrays/Pass{pas}/fbg{config}.npy')) - fpion_GEn2 - facc_GEn2 - fFSI_GEn2
Efbg_GEn2 = np.sum(np.load(f'../analysis/CorrectionArrays/Pass{pas}/fbgE{config}.npy'))
Abg_GEn2 = np.sum(np.load(f'../analysis/CorrectionArrays/Pass{pas}/Abg{config}.npy'))
Ebg_GEn2 = np.sum(np.load(f'../analysis/CorrectionArrays/Pass{pas}/AbgE{config}.npy'))
Efbg_GEn2=np.sqrt(Efbg_GEn2**2+Efpion_GEn2**2+Efacc_GEn2**2+Efnitro_GEn2**2)
#______________________________________GEN3___________________________________________________
config="3"

facc_GEn3 = np.sum(np.load(f'../analysis/CorrectionArrays/Pass{pas}/facc{config}.npy'))
Efacc_GEn3 = np.sum(np.load(f'../analysis/CorrectionArrays/Pass{pas}/faccE{config}.npy'))
Aacc_GEn3 = np.sum(np.load(f'../analysis/CorrectionArrays/Pass{pas}/Aacc{config}.npy'))
Eacc_GEn3 = np.sum(np.load(f'../analysis/CorrectionArrays/Pass{pas}/AaccE{config}.npy'))

fproton_GEn3 = np.sum(np.load(f'../analysis/CorrectionArrays/Pass{pas}/fproton{config}.npy'))
Efproton_GEn3 = np.sum(np.load(f'../analysis/CorrectionArrays/Pass{pas}/fprotonE{config}.npy'))
Aproton_GEn3 = np.sum(np.load(f'../analysis/CorrectionArrays/Pass{pas}/Aproton{config}.npy'))
Eproton_GEn3 = .005 * Aproton_GEn3

fpion_GEn3 = .01
Efpion_GEn3 = .005 * fpion_GEn3
Apion_GEn3 = 0
Epion_GEn3 = .005 * Apion_GEn3

fFSI_GEn3 = 0
EfFSI_GEn3 = .005 * fFSI_GEn3
AFSI_GEn3 = 0
EFSI_GEn3 = .005 * AFSI_GEn3

fnitro_GEn3 = .0157
Efnitro_GEn3 = .005 * fnitro_GEn3

Pneutron_GEn3 = .95
Eneutron_GEn3 = .005 * Pneutron_GEn3

fbg_GEn3 = np.sum(np.load(f'../analysis/CorrectionArrays/Pass{pas}/fbg{config}.npy')) - fpion_GEn3 - facc_GEn3 - fFSI_GEn3
Efbg_GEn3 = np.sum(np.load(f'../analysis/CorrectionArrays/Pass{pas}/fbgE{config}.npy'))
Abg_GEn3 = np.sum(np.load(f'../analysis/CorrectionArrays/Pass{pas}/Abg{config}.npy'))
Ebg_GEn3 = np.sum(np.load(f'../analysis/CorrectionArrays/Pass{pas}/AbgE{config}.npy'))
Efbg_GEn3=np.sqrt(Efbg_GEn3**2+Efpion_GEn3**2+Efacc_GEn3**2+Efnitro_GEn3**2)

#______________________________________GEN4___________________________________________________
config="4"
facc_GEn4 = np.sum(np.load(f'../analysis/CorrectionArrays/Pass{pas}/facc{config}.npy'))
Efacc_GEn4 = np.sum(np.load(f'../analysis/CorrectionArrays/Pass{pas}/faccE{config}.npy'))
Aacc_GEn4 = np.sum(np.load(f'../analysis/CorrectionArrays/Pass{pas}/Aacc{config}.npy'))
Eacc_GEn4 = np.sum(np.load(f'../analysis/CorrectionArrays/Pass{pas}/AaccE{config}.npy'))

fproton_GEn4 = np.sum(np.load(f'../analysis/CorrectionArrays/Pass{pas}/fproton{config}.npy'))
Efproton_GEn4 = np.sum(np.load(f'../analysis/CorrectionArrays/Pass{pas}/fprotonE{config}.npy'))
Aproton_GEn4= np.sum(np.load(f'../analysis/CorrectionArrays/Pass{pas}/Aproton{config}.npy'))
Eproton_GEn4 = .005 * Aproton_GEn4

fpion_GEn4 = 0.01
Efpion_GEn4 = .005 * fpion_GEn4
Apion_GEn4 = 0
Epion_GEn4 = .005 * Apion_GEn4

fFSI_GEn4 = 0
EfFSI_GEn4 = .005 * fFSI_GEn4
AFSI_GEn4 = 0
EFSI_GEn4 = .005 * AFSI_GEn4

fnitro_GEn4 = .0157
Efnitro_GEn4 = .005 * fnitro_GEn4

Pneutron_GEn4 = .95
Eneutron_GEn4 = .005 * Pneutron_GEn4

fbg_GEn4 = np.sum(np.load(f'../analysis/CorrectionArrays/Pass{pas}/fbg{config}.npy')) - fpion_GEn4 - facc_GEn4 - fFSI_GEn4
Efbg_GEn4 = np.sum(np.load(f'../analysis/CorrectionArrays/Pass{pas}/fbgE{config}.npy'))
Abg_GEn4 = np.sum(np.load(f'../analysis/CorrectionArrays/Pass{pas}/Abg{config}.npy'))
Ebg_GEn4 = np.sum(np.load(f'../analysis/CorrectionArrays/Pass{pas}/AbgE{config}.npy'))
Efbg_GEn4=np.sqrt(Efbg_GEn4**2+Efpion_GEn4**2+Efacc_GEn4**2+Efnitro_GEn4**2)
# Define the data as a dictionary and round values to 5 decimal places
data = {
    "Variable": [
        r"$\mathbf{f_{acc}}$", r"$\mathbf{A_{acc}}$", r"$\mathbf{f_{proton}}$", r"$\mathbf{A_{proton}}$",
        r"$\mathbf{f_{pion}}$", r"$\mathbf{A_{pion}}$", r"$\mathbf{f_{FSI}}$", r"$\mathbf{A_{FSI}}$",
        r"$\mathbf{f_{nitro}}$", r"$\mathbf{P_{neutron}}$", r"$\mathbf{f_{inel}}$", r"$\mathbf{A_{inel}}$"
    ],
    "GEn2 Value": [
        round(facc_GEn2, 5), round(Aacc_GEn2, 5), round(fproton_GEn2, 5), round(Aproton_GEn2, 5),
        round(fpion_GEn2, 5), round(Apion_GEn2, 5), round(fFSI_GEn2, 5), round(AFSI_GEn2, 5),
        round(fnitro_GEn2, 5), round(Pneutron_GEn2, 5), round(fbg_GEn2, 5), round(Abg_GEn2, 5)
    ],
    r"GEn2 $\mathbf{\sigma}$": [
        round(Efacc_GEn2, 5), round(Eacc_GEn2, 5), round(Efproton_GEn2, 5), round(Eproton_GEn2, 5),
        round(Efpion_GEn2, 5), round(Epion_GEn2, 5), round(EfFSI_GEn2, 5), round(EFSI_GEn2, 5),
        round(Efnitro_GEn2, 5), round(Eneutron_GEn2, 5), round(Efbg_GEn2, 5), round(Ebg_GEn2, 5)
    ],
    "GEn3 Value": [
        round(facc_GEn3, 5), round(Aacc_GEn3, 5), round(fproton_GEn3, 5), round(Aproton_GEn3, 5),
        round(fpion_GEn3, 5), round(Apion_GEn3, 5), round(fFSI_GEn3, 5), round(AFSI_GEn3, 5),
        round(fnitro_GEn3, 5), round(Pneutron_GEn3, 5), round(fbg_GEn3, 5), round(Abg_GEn3, 5)
    ],
    r"GEn3 $\mathbf{\sigma}$": [
        round(Efacc_GEn3, 5), round(Eacc_GEn3, 5), round(Efproton_GEn3, 5), round(Eproton_GEn3, 5),
        round(Efpion_GEn3, 5), round(Epion_GEn3, 5), round(EfFSI_GEn3, 5), round(EFSI_GEn3, 5),
        round(Efnitro_GEn3, 5), round(Eneutron_GEn3, 5), round(Efbg_GEn3, 5), round(Ebg_GEn3, 5)
    ],
    "GEn4 Value": [
        round(facc_GEn4, 5), round(Aacc_GEn4, 5), round(fproton_GEn4, 5), round(Aproton_GEn4, 5),
        round(fpion_GEn4, 5), round(Apion_GEn4, 5), round(fFSI_GEn4, 5), round(AFSI_GEn4, 5),
        round(fnitro_GEn4, 5), round(Pneutron_GEn4, 5), round(fbg_GEn4, 5), round(Abg_GEn4, 5)
    ],
    r"GEn4 $\mathbf{\sigma}$": [
        round(Efacc_GEn4, 5), round(Eacc_GEn4, 5), round(Efproton_GEn4, 5), round(Eproton_GEn4, 5),
        round(Efpion_GEn4, 5), round(Epion_GEn4, 5), round(EfFSI_GEn4, 5), round(EFSI_GEn4, 5),
        round(Efnitro_GEn4, 5), round(Eneutron_GEn4, 5), round(Efbg_GEn4, 5), round(Ebg_GEn4, 5)
    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Plot the DataFrame using matplotlib
fig, ax = plt.subplots(figsize=(18, 10))  # set size frame
ax.axis('tight')
ax.axis('off')

# Create the table and adjust the font size
table = ax.table(cellText=df.values, colLabels=[
    r"$\mathbf{Variable}$", 
    r"$\mathbf{Value-GEN2}$", r"$\mathbf{\sigma}$", 
    r"$\mathbf{Value-GEN3}$", r"$\mathbf{\sigma}$", 
    r"$\mathbf{Value-GEN4}$", r"$\mathbf{\sigma}$"], cellLoc='center', loc='center')
table.auto_set_font_size(False)
table.set_fontsize(12)

# Set a larger font size for the variable column and bold headers
for (i, j), cell in table.get_celld().items():
    if i == 0:
        cell.set_text_props(fontsize=14, weight='bold')
    if j == 0 and i > 0:
        cell.set_text_props(fontsize=14, weight='bold')

# Adjust column widths and cell padding
table.auto_set_column_width([0, 1, 2, 3, 4, 5, 6])
for (i, j), cell in table.get_celld().items():
    cell.set_edgecolor('black')
    cell.set_linewidth(1.5)
    cell.set_height(0.1)
    cell.set_text_props(ha='center', va='center')

plt.savefig("tables/Corrections")
